# %% [markdown]
# #Projekt_3

# %% [markdown]
# ## Moduły

# %%
import os
import json
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
import torch
import torch.nn as nn
import sys
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision.utils import save_image
from tqdm import tqdm
import torchvision.models as models
from google.colab import drive
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Upload datasetu z dysku

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT_PROJECT_FOLDER = '/content/drive/MyDrive/projekt_3'

# %% [markdown]
# ##Dataset

# %%
class PhongDataset(Dataset):
    # Zakresy teoretyczne wektorów relatywnych:
    MAX_VECTOR_RANGE = 30.0

    SHININESS_MIN = 3.0
    SHININESS_MAX = 20.0

    def __init__(self, root_dir):
        self.root_dir = root_dir

        self.files = sorted([f for f in os.listdir(root_dir) if f.endswith('.json')])

        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])

    def __len__(self):
        return len(self.files)

    @staticmethod
    def normalize_data(rel_light, rel_view, diffuse, shininess):
        norm_vector = []

        # w. Relatywne )
        # [-30, 30] -> [-1, 1]
        norm_vector.extend([x / PhongDataset.MAX_VECTOR_RANGE for x in rel_light])
        norm_vector.extend([x / PhongDataset.MAX_VECTOR_RANGE for x in rel_view])

        # [0.0, 1.0] do [-1, 1]
        norm_vector.extend([(x * 2.0) - 1.0 for x in diffuse])

        # [3.0, 20.0] do [-1, 1]
        s_01 = (shininess - PhongDataset.SHININESS_MIN) / (PhongDataset.SHININESS_MAX - PhongDataset.SHININESS_MIN)
        s_norm = (s_01 * 2.0) - 1.0
        norm_vector.append(s_norm)

        return norm_vector

    def __getitem__(self, idx):
        json_name = self.files[idx]
        json_path = os.path.join(self.root_dir, json_name)

        with open(json_path, 'r') as f:
            data = json.load(f)

        input_list = PhongDataset.normalize_data(
            rel_light=data["relative_light_vector"],
            rel_view=data["relative_view_vector"],
            diffuse=data["material_diffuse"],
            shininess=data["material_shininess"]
        )

        input_tensor = torch.tensor(input_list, dtype=torch.float32)

        # obraz
        img_name = data["file_name"]
        img_path = os.path.join(self.root_dir, img_name)

        image = Image.open(img_path).convert("RGB")
        image_tensor = self.transform(image)

        return input_tensor, image_tensor

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn


PARAM_DIM = 10
IMG_CHANNELS = 3
IMG_SIZE = 128

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.input_dim = PARAM_DIM

        # Liniowa transformacja do 4x4
        # do 512
        self.fc = nn.Sequential(
            nn.Linear(self.input_dim, 512 * 4 * 4),
            nn.BatchNorm1d(512 * 4 * 4),
            nn.LeakyReLU(0.2, inplace=True)
        )

        #Upsample (x2) -> CoordConv -> Conv2d -> BN -> LeakyReLU

        self.block1 = self._make_gen_block(512, 256) # 4 -> 8
        self.block2 = self._make_gen_block(256, 128) # 8 -> 16
        self.block3 = self._make_gen_block(128, 64)  # 16 -> 32
        self.block4 = self._make_gen_block(64, 32)   # 32 -> 64

        self.last_block = nn.Sequential(
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, inplace=True),


            nn.Conv2d(32, IMG_CHANNELS, kernel_size=3, stride=1, padding=1, bias=False),
            nn.Tanh()
        )

    def _make_gen_block(self, in_c, out_c):
        return nn.Sequential(
            nn.Upsample(scale_factor=2, mode='nearest'),

            nn.Conv2d(in_c, out_c, kernel_size=3, stride=1, padding=1, bias=False),

            nn.BatchNorm2d(out_c),
            nn.LeakyReLU(0.2, inplace=True)
        )

    def forward(self, noise, labels):

        x = self.fc(labels)
        x = x.view(-1, 512, 4, 4) # [Batch, 512, 4, 4]

        x = self.block1(x) # 8x8
        x = self.block2(x) # 16x16
        x = self.block3(x) # 32x32
        x = self.block4(x) # 64x64

        img = self.last_block(x) # 128x128

        return img

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.label_embedding = nn.Sequential(
            nn.Linear(PARAM_DIM, 128),
            nn.LeakyReLU(0.2, inplace=True)
        )

        self.image_processing = nn.Sequential(
            # Input: 3 x 128 x 128

            # Layer 1: 128 -> 64
            nn.Conv2d(IMG_CHANNELS, 16, kernel_size=4, stride=2, padding=1, bias=False), # Start od 16
            nn.LeakyReLU(0.2, inplace=True),

            # Layer 2: 64 -> 32
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False), # Max 32
            nn.InstanceNorm2d(32, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # Layer 3: 32 -> 16
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # Max 64
            nn.InstanceNorm2d(64, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # Layer 4: 16 -> 8
            # Tu kończymy (nie schodzimy do 4x4). Obrazek 8x8 ma wystarczająco mało detali.
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # Max 128
            nn.InstanceNorm2d(128, affine=True),
            nn.LeakyReLU(0.2, inplace=True),
        )


        self.flatten_size = 128 * 8 * 8

        self.classifier = nn.Sequential(
            nn.Linear(self.flatten_size + 128, 256),
            nn.LeakyReLU(0.2, inplace=True),

            # DROPOUT 0.5 - agresywne zapobieganie pamieci
            nn.Dropout(0.5),

            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        features = self.image_processing(img)
        features_flat = features.view(features.size(0), -1)

        label_emb = self.label_embedding(labels)
        concat_input = torch.cat((features_flat, label_emb), dim=1)

        validity = self.classifier(concat_input)
        return validity

def weights_init(m):
    classname = m.__class__.__name__
    if 'Conv' in classname:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif 'BatchNorm' in classname:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# test
if __name__ == "__main__":
    batch_size = 5
    noise = torch.randn(batch_size, LATENT_DIM)
    params = torch.randn(batch_size, PARAM_DIM)

    G = Generator()
    fake_imgs = G(noise, params)
    print(f"Generator output: {fake_imgs.shape}") #  [5, 3, 128, 128]

    D = Discriminator()
    validity = D(fake_imgs, params)
    print(f"Discriminator output: {validity.shape}") #  [5, 1]
# Out:
# Generator output: torch.Size([5, 3, 128, 128])
# Discriminator output: torch.Size([5, 1])

# %% [markdown]
# ##Parametry treningu

# %%
LEARNING_RATE_GEN = 0.0001
LEARNING_RATE_DISC = 0.000005
BATCH_SIZE = 32
NUM_EPOCHS = 270
L1_LAMBDA = 20.0

LOAD_MODEL = True
START_EPOCH =0

DISC_WARMUP_EPOCHS = 0


dataset_dir = ROOT_PROJECT_FOLDER + "/dataset"
checkpoint_dir = ROOT_PROJECT_FOLDER + "/model_3_checkpoints_v3"
evaluation_dir = ROOT_PROJECT_FOLDER + "/model_3_evaluation_samples_v3" #v3 - dynamic

# %% [markdown]
# ## Trening

# %%
def get_loaders(root_dir, batch_size):
    # Podział: Train (2200), Val (200), Test (600)
    # Deterministyczny - manual_seed(42)

    dataset = PhongDataset(root_dir)

    total_len = len(dataset)
    test_len = 600
    val_len = 200
    train_len = total_len - test_len - val_len # (2200)

    generator = torch.Generator().manual_seed(42)

    train_ds, val_ds, test_ds = random_split(
        dataset,
        [train_len, val_len, test_len],
        generator=generator
    )

    print(f"Podział danych: Train={len(train_ds)}, Val={len(val_ds)}, Test={len(test_ds)}")

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True) #pod cpu
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"


# Definicje globalne (potrzebne do normalizacji VGG)
VGG_WEIGHT = 0.6
WARMUP_EPOCHS = 60
VGG_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1).to(DEVICE)
VGG_STD = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1).to(DEVICE)

def setup_vgg_model(device):

    vgg = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1).features.to(device)


    feature_layers = [4, 9, 16]
    blocks = []

    current_layer = 0
    for i in feature_layers:
        block = nn.Sequential(*vgg[current_layer:i]).eval()
        for p in block.parameters():
            p.requires_grad = False
        blocks.append(block)
        current_layer = i

    return nn.ModuleList(blocks).to(device)

def calculate_vgg_loss(vgg_model, fake_img, real_img):
    fake = nn.functional.interpolate(fake_img, size=(224, 224), mode='bilinear', align_corners=False)
    real = nn.functional.interpolate(real_img, size=(224, 224), mode='bilinear', align_corners=False)

    fake = (fake - VGG_MEAN) / VGG_STD
    real = (real - VGG_MEAN) / VGG_STD


    loss = 0.0
    for block in vgg_model:
        fake = block(fake)
        real = block(real)

        loss += torch.nn.functional.l1_loss(fake, real)

    return loss

os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(evaluation_dir, exist_ok=True)



def train_cooldown_fn(gen, loader, opt_gen, l1_loss, epoch):
    loop = tqdm(loader, leave=True)

    for idx, (inputs, real_images) in enumerate(loop):
        inputs = inputs.to(DEVICE)
        real_images = real_images.to(DEVICE)


        fake_images = gen(None, inputs)

        loss_g_l1, raw_l1, _ = calculate_masked_loss(fake_images, real_images, lambda_val=1.0) # Lambda nie ma znaczenia bo jest jeden loss

        g_loss = loss_g_l1

        gen.zero_grad()
        g_loss.backward()
        opt_gen.step()

        loop.set_postfix(Mode="COOLDOWN", L1=f"{raw_l1.item():.5f}")

def calculate_masked_loss(fake, real, lambda_val):

    l1_diff = torch.abs(fake - real)


    mask = (real > -0.98).float()
    mask_pct = mask.mean().item() # Ile % obrazka to kula

    weights = 1.0 + (mask * 10)


    loss = (l1_diff * weights).mean() * lambda_val

    return loss, l1_diff.mean(), mask_pct

def save_checkpoint(model, optimizer, filename="checkpoint.pth"):
    print(f"=> Zapisywanie checkpointu do {filename}")
    checkpoint = {
        "state_dict": model.state_dict(),
        "optimizer": optimizer.state_dict(),
    }
    torch.save(checkpoint, filename)

def load_checkpoint(checkpoint_file, model, optimizer, lr):
    print(f"=> Wczytywanie checkpointu {checkpoint_file}")
    checkpoint = torch.load(checkpoint_file, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

    for param_group in optimizer.param_groups:
        param_group["lr"] = lr

def check_accuracy(val_loader, gen, disc, device, epoch, l1_loss_fn, bce_loss_fn, folder=evaluation_dir):
    gen.eval()
    disc.eval()


    total_raw_l1 = 0.0
    total_masked_l1 = 0.0
    total_g_loss = 0.0
    total_d_loss = 0.0

    total_fake_score = 0.0
    total_real_score = 0.0

    correct_real = 0
    correct_fake = 0
    total_samples = 0
    num_batches = 0

    print(f"\n=== RAPORT VALIDATION (EPOCH {epoch}) ===")

    with torch.no_grad():
        for i, (inputs, targets) in enumerate(val_loader):
            inputs = inputs.to(device)
            targets = targets.to(device)
            batch_size = inputs.shape[0]

            fake_images = gen(None, inputs)


            # Real
            d_real = disc(targets, inputs)
            loss_d_real = bce_loss_fn(d_real, torch.ones_like(d_real)) # Bez label smoothing w eval

            # Fake
            d_fake = disc(fake_images, inputs)
            loss_d_fake = bce_loss_fn(d_fake, torch.zeros_like(d_fake))

            # Loss D
            d_loss = (loss_d_real * 1.5 + loss_d_fake * 0.5) /2
            total_d_loss += d_loss.item()


            total_real_score += d_real.mean().item()
            total_fake_score += d_fake.mean().item()


            correct_real += (d_real > 0.5).sum().item()
            correct_fake += (d_fake < 0.5).sum().item()
            total_samples += batch_size


            loss_g_gan = bce_loss_fn(d_fake, torch.ones_like(d_fake))

            masked_l1, raw_l1, _ = calculate_masked_loss(fake_images, targets, L1_LAMBDA)

            g_loss = loss_g_gan + masked_l1

            total_g_loss += g_loss.item()
            total_masked_l1 += masked_l1.item()
            total_raw_l1 += raw_l1.item()

            num_batches += 1

            if i == 0:
                if False: #wylaczenie

                    for j in range(min(16, len(targets))):

                        # Pojedyncze pary

                        real_img = targets[j:j+1]

                        fake_img = fake_images[j:j+1]



                        # Pomiary lokalne

                        l1_val = torch.abs(fake_img - real_img).mean().item()

                        mask = (real_img > -0.98).float()

                        mask_p = mask.mean().item()



                        weights = 1.0 + (mask * 19.0)

                        l1_weighted = (torch.abs(fake_img - real_img) * weights).mean().item() * L1_LAMBDA


                        sc_real = d_real[j].item()

                        sc_fake = d_fake[j].item()



                        status = ""

                        if sc_fake > 0.5: status += "OSZUKANY! "



                        print(f"{j:<3} | {sc_real:.4f}   | {sc_fake:.4f}   | {l1_val:.4f}   | {l1_weighted:.4f}   | {mask_p*100:.1f}%  | {status}")

                debug_mask = (targets > -0.98).float()
                img_grid = torch.cat((targets[:16], fake_images[:16], debug_mask[:16]), dim=0)
                save_image(img_grid * 0.5 + 0.5, f"{folder}/epoch_{epoch}.png")

    avg_raw_l1 = total_raw_l1 / num_batches
    avg_masked_l1 = total_masked_l1 / num_batches
    avg_g_loss = total_g_loss / num_batches
    avg_d_loss = total_d_loss / num_batches

    avg_real_score = total_real_score / num_batches
    avg_fake_score = total_fake_score / num_batches

    acc_real = correct_real / total_samples
    acc_fake = correct_fake / total_samples

    print("-" * 75)
    print(f"LOSSES  => G: {avg_g_loss:.4f} | D: {avg_d_loss:.4f}")
    print(f"L1      => Raw: {avg_raw_l1:.4f} | Weighted: {avg_masked_l1:.4f}")
    print(f"SCORES  => Real(D): {avg_real_score:.4f} | Fake(D): {avg_fake_score:.4f}")
    print(f"ACC     => Real: {acc_real:.2%} | Fake: {acc_fake:.2%}")
    print("=" * 75)

    gen.train()
    disc.train()


ACC_TARGET_MIN = 0.65
ACC_TARGET_MAX = 0.90
MAX_D_REPEATS = 3
MAX_G_REPEATS = 2

CONSTANT_NOISE_STD = 0.01

def train_dynamic_fn(disc, gen, loader, opt_disc, opt_gen, l1_loss, bce, epoch, vgg_criterion):
    loop = tqdm(loader, leave=True)

    d_total_samples = 0
    d_real_correct = 0
    d_fake_correct = 0


    total_d_boosts = 0
    total_g_boosts = 0
    total_d_steps = 0
    total_g_steps = 0

    for idx, (inputs, real_images) in enumerate(loop):
        inputs = inputs.to(DEVICE)
        real_images = real_images.to(DEVICE)
        batch_size = inputs.shape[0]


        d_loops = 0

        while d_loops < MAX_D_REPEATS:
            with torch.no_grad():
                fake_images = gen(None, inputs)

            noise = torch.randn_like(real_images) * CONSTANT_NOISE_STD

            real_noisy = real_images + noise
            fake_noisy = fake_images.detach() + noise # Detach + Szum

            d_real = disc(real_noisy, inputs)
            loss_d_real = bce(d_real, torch.ones_like(d_real) * 0.9)

            d_fake = disc(fake_noisy, inputs)
            loss_d_fake = bce(d_fake, torch.zeros_like(d_fake))

            loss_d = (loss_d_real * 1.5 + loss_d_fake * 0.5) /2 #211

            acc_real = (d_real > 0.5).float().mean().item()
            acc_fake = (d_fake < 0.5).float().mean().item()
            current_acc = (acc_real + acc_fake) / 2



            is_unbalanced = abs(acc_real - acc_fake) > 0.4
            is_blind_to_real = acc_real < 0.45
            is_weak_overall = current_acc < ACC_TARGET_MAX

            # Decyzja o treningu D
            should_train_d = (is_weak_overall or is_blind_to_real or is_unbalanced)

            if current_acc > 0.98: should_train_d = False

            if should_train_d:
                disc.zero_grad()
                loss_d.backward()
                opt_disc.step()
                d_loops += 1
                total_d_steps += 1
            else:
                break
            if current_acc > ACC_TARGET_MIN and not is_blind_to_real:
                break

        # Statystyki
        d_real_correct += (d_real > 0.5).sum().item()
        d_fake_correct += (d_fake < 0.5).sum().item()
        d_total_samples += batch_size

        if d_loops > 1: total_d_boosts += 1


        # Jeśli D jest za madry, G trenuje 2 razy
        g_repeats = MAX_G_REPEATS if current_acc >= ACC_TARGET_MAX else 1
        if g_repeats > 1: total_g_boosts += 1

        for i in range(g_repeats):
            fake_for_g = gen(None, inputs)
            noise_g = torch.randn_like(fake_for_g) * CONSTANT_NOISE_STD
            fake_g_noisy = fake_for_g + noise_g

            d_fake_g = disc(fake_g_noisy, inputs)

            loss_g_gan = bce(d_fake_g, torch.ones_like(d_fake_g))
            loss_g_l1, raw_l1, _ = calculate_masked_loss(fake_for_g, real_images, L1_LAMBDA)

            g_loss = loss_g_gan + loss_g_l1

            gen.zero_grad()
            g_loss.backward()
            opt_gen.step()
            total_g_steps += 1


        status_msg = "OK"
        if d_loops > 1: status_msg = f"D+{d_loops-1}"
        if g_repeats > 1: status_msg = f"G+{g_repeats-1}"

        loop.set_postfix(
            St=status_msg,
            D=f"{loss_d.item():.3f}",
            G=f"{g_loss.item():.2f}",
            L1=f"{raw_l1.item():.4f}",
            L_W=f"{loss_g_l1.item():.2f}",
            AccR=f"{acc_real:.2f}",
            AccF=f"{acc_fake:.2f}"
        )

    # --- PODSUMOWANIE EPOKI (Pod paskiem) ---
    final_acc_real = d_real_correct / d_total_samples if d_total_samples > 0 else 0
    final_acc_fake = d_fake_correct / d_total_samples if d_total_samples > 0 else 0

    print(f"\n[Dynamic Stats] D_Boosts: {total_d_boosts} | G_Boosts: {total_g_boosts} || Total Steps: D={total_d_steps}, G={total_g_steps}")
    print(f"[Epoch Stats]   Acc Real: {final_acc_real:.2%} | Acc Fake: {final_acc_fake:.2%}")

def train_fn(disc, gen, loader, opt_disc, opt_gen, l1_loss, bce, epoch, vgg_criterion):
    loop = tqdm(loader, leave=True)

    d_real_correct = 0
    d_fake_correct = 0
    d_total = 0

    for idx, (inputs, real_images) in enumerate(loop):
        inputs = inputs.to(DEVICE)
        real_images = real_images.to(DEVICE)
        batch_size = inputs.shape[0]

       #WARMUP
        if epoch < WARMUP_EPOCHS:
            fake_images = gen(None, inputs)

            loss_g_l1, raw_l1, mask_pct = calculate_masked_loss(fake_images, real_images, L1_LAMBDA)

            # Tylko L1
            g_loss = loss_g_l1

            gen.zero_grad()
            g_loss.backward()
            opt_gen.step()

            loop.set_postfix(Mode="WARMUP_L1", L1=f"{raw_l1:.4f}", TotalG=f"{g_loss.item():.2f}")

        else:
            freeze_gen = epoch < (START_EPOCH + DISC_WARMUP_EPOCHS)
            mode_name = "REHAB_DISC" if freeze_gen else "GAN_TRAIN"

            #  DYSKRYMINATOR
            with torch.set_grad_enabled(not freeze_gen):
                fake_images = gen(None, inputs)

            # Real
            d_real = disc(real_images, inputs)
            loss_d_real = bce(d_real, torch.ones_like(d_real) * 0.9) # Label smoothing
            d_real_correct += (d_real > 0.5).sum().item()

            # Fake
            d_fake = disc(fake_images.detach(), inputs)
            loss_d_fake = bce(d_fake, torch.zeros_like(d_fake))
            d_fake_correct += (d_fake < 0.5).sum().item()

            loss_d = (loss_d_real + loss_d_fake) / 2

            disc.zero_grad()
            loss_d.backward()
            opt_disc.step()

            #  GENERATOR
            if not freeze_gen:
                # Trenujemy G tylko w trybie GAN_TRAIN

                d_fake_for_gen = disc(fake_images, inputs)
                loss_g_gan = bce(d_fake_for_gen, torch.ones_like(d_fake_for_gen))

                loss_g_l1, raw_l1, mask_pct = calculate_masked_loss(fake_images, real_images, L1_LAMBDA)

                g_loss = loss_g_gan + loss_g_l1

                gen.zero_grad()
                g_loss.backward()
                opt_gen.step()


                log_g_loss = g_loss.item()
                log_l1 = raw_l1.item()
            else:
                with torch.no_grad():
                     _, log_l1, _ = calculate_masked_loss(fake_images, real_images, L1_LAMBDA)
                log_g_loss = 0.0

            # Logowanie
            d_total += batch_size
            acc_real = d_real_correct / d_total if d_total > 0 else 0
            acc_fake = d_fake_correct / d_total if d_total > 0 else 0

            loop.set_postfix(
                Mode=mode_name,
                D=f"{loss_d.item():.4f}",
                G=f"{log_g_loss:.2f}",
                L1=f"{log_l1:.4f}",
                AccR=f"{acc_real:.2f}",
                AccF=f"{acc_fake:.2f}"
            )

# %%
print(f"Urządzenie: {DEVICE}")
print(f"Lambda L1: {L1_LAMBDA}")

gen = Generator().to(DEVICE)
disc = Discriminator().to(DEVICE)

gen.apply(weights_init)
disc.apply(weights_init)

opt_gen = optim.Adam(gen.parameters(), lr=LEARNING_RATE_GEN, betas=(0.5, 0.999))
opt_disc = optim.Adam(disc.parameters(), lr=LEARNING_RATE_DISC, betas=(0.5, 0.999)) # disc uczy się 4 razy wolniej

vgg_criterion = setup_vgg_model(DEVICE)
print("Zainicjalizowano Generator VGG Loss (VGG16).")

bce = nn.BCELoss()
l1_loss = nn.L1Loss()

train_loader, val_loader, test_loader = get_loaders(dataset_dir, BATCH_SIZE)

if LOAD_MODEL:
    current_lr_gen = LEARNING_RATE_GEN
    current_lr_disc = LEARNING_RATE_DISC
    load_checkpoint(f"{checkpoint_dir}/gen_epoch_{START_EPOCH}.pth", gen, opt_gen, current_lr_gen)
    load_checkpoint(f"{checkpoint_dir}/disc_epoch_{START_EPOCH}.pth", disc, opt_disc, current_lr_disc)
    print(f"--> Wznowiono trening od epoki {START_EPOCH}. Nowe LR: G={current_lr_gen}, D={current_lr_disc}")
# Out:
# Urządzenie: cpu
# Lambda L1: 20.0
# Zainicjalizowano Generator VGG Loss (VGG16).
# Podział danych: Train=2200, Val=200, Test=600

# %%
train_info = []

os.makedirs(checkpoint_dir, exist_ok=True)
train_params = f"\n\n### PARAMETRY TRENINGU ### LEARNING_RATE_GEN={LEARNING_RATE_GEN}\nLEARNING_RATE_DISC={LEARNING_RATE_DISC}\nBATCH_SIZE={BATCH_SIZE}\nNUM_EPOCHS={NUM_EPOCHS}\nL1_LAMBDA={L1_LAMBDA}"
with open(f"{checkpoint_dir}/train_params.txt", "w") as f:
  f.write(train_params)

for epoch in range(START_EPOCH + 1, START_EPOCH + 1 + NUM_EPOCHS):
    print(f"Epoch [{epoch}/{START_EPOCH + NUM_EPOCHS}]")

    train_dynamic_fn(disc, gen, train_loader, opt_disc, opt_gen, l1_loss, bce, epoch, vgg_criterion)
    info = check_accuracy(val_loader, gen, disc, DEVICE, epoch, l1_loss,bce)

    train_info.append(info)

    if epoch == 50 and epoch == 100 and epoch == 150 and epoch == 180 and epoch >= 197:
      save_checkpoint(gen, opt_gen, filename=f"{checkpoint_dir}/gen_epoch_{epoch}.pth")
      save_checkpoint(disc, opt_disc, filename=f"{checkpoint_dir}/disc_epoch_{epoch}.pth")

# %% [markdown]
# ## Wyniki

# %%
LOAD_MODEL=True
if LOAD_MODEL:
    current_lr_gen = LEARNING_RATE_GEN
    load_checkpoint(f"{checkpoint_dir}/gen_epoch_{NUM_EPOCHS}.pth", gen, opt_gen, current_lr_gen)
# Out:
# => Wczytywanie checkpointu /content/drive/MyDrive/projekt_3/model_3_checkpoints_v3/gen_epoch_270.pth

# %%
test_ds_folder = ROOT_PROJECT_FOLDER + f"/test_results/model_3_{NUM_EPOCHS}"
result_folder = ROOT_PROJECT_FOLDER + "/model_3_metryki"

target_folder = test_ds_folder + "/target"
pred_folder = test_ds_folder + "/pred"

# %% [markdown]
# ### Metryki

# %%
# !pip install lpips
# !pip install flip-evaluator

from skimage.metrics import structural_similarity as ssim
import lpips
from flip_evaluator import evaluate
from scipy.spatial.distance import directed_hausdorff
import cv2
from torchvision.utils import make_grid
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.24.0+cu126)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4
# Collecting flip-evaluator
#   Downloading flip_evaluator-1.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Downloading flip_evaluator-1.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (415 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.2/415.2 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: flip-evaluator
# Successfully installed flip-evaluator-1.7

# %%
def calc_hausdorff(orginal=np.ndarray, proccessed=np.ndarray) -> float:
  threshold_h, _ = cv2.threshold(cv2.cvtColor(orginal, cv2.COLOR_RGB2GRAY), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  orginal_edges = cv2.Canny(orginal, threshold1=threshold_h * 0.3, threshold2=threshold_h)

  threshold_h, _ = cv2.threshold(cv2.cvtColor(proccessed, cv2.COLOR_RGB2GRAY), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  proccessed_edges = cv2.Canny(proccessed, threshold1=threshold_h * 0.3, threshold2=threshold_h)

  orginal_points_edges = np.column_stack(np.where(orginal_edges > 0))
  proccessed_points_edges = np.column_stack(np.where(proccessed_edges > 0))

  return max(directed_hausdorff(orginal_points_edges, proccessed_points_edges)[0], directed_hausdorff(proccessed_points_edges, orginal_points_edges)[0])

# %%
def read_image(path: str):
  return cv2.imread(path, cv2.IMREAD_COLOR_RGB)

# %%
target_content = os.listdir(target_folder)
pred_content = os.listdir(pred_folder)

# %%
target_content = [item for item in target_content if item.endswith(".png")]
pred_content = [item for item in pred_content if item.endswith(".png")]

# %%
print(len(target_content))
print(len(pred_content))
# Out:
# 600
# 600

# %%
def as_tensor(image):
  image = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0)
  image  = image * 2 - 1

  return image.type(torch.float32)

# %%
def calc_metrics(gen, device, lpips_net='squeeze', result_folder=None):
  print(f"Urządzenie: {DEVICE}")

  gen.eval()

  loss_lpips = lpips.LPIPS(net=lpips_net).to(device)

  # metryki
  ssim_metric      = []
  lpips_metric     = []
  flip_metric      = []
  hausdorff_metric = []

  mertric_str = ""

  i = 0
  dynamicRange = "LDR"
  with torch.no_grad():
      for target_name in target_content:
        fullpath_target = target_folder + "/" + target_name
        fullpath_pred = pred_folder + "/" + target_name

        target_img = read_image(fullpath_target)
        pred_img = read_image(fullpath_pred)

        target_img_f = target_img.astype(np.float32) / 255.0
        pred_img_f = pred_img.astype(np.float32) / 255.0

        print(f"\ttarget_img_f: min={target_img_f.min().item()}, max={target_img_f.max().item()}")
        print(f"\tpred_img_f: min={pred_img_f.min().item()}, max={pred_img_f.max().item()}")

        ## ------- SSIM ----------
        ssim_metric.append(ssim(target_img, pred_img, full=False, multichannel=True, channel_axis=-1, data_range=1))

        ## ------- LIPIS ----------

        target_tensor = as_tensor(target_img_f)
        pred_tensor = as_tensor(pred_img_f)

        print(f"\ttarget_tensor: min={target_tensor.min().item()}, max={target_tensor.max().item()}")
        print(f"\tpred_tensor: min={pred_tensor.min().item()}, max={pred_tensor.max().item()}")

        lpips_metric.append(loss_lpips(target_tensor, pred_tensor).item())

        ## ------- FLIP ----------
        flip_info = evaluate(target_img_f, pred_img_f, dynamicRange)
        flip_metric.append(flip_info[1])

        ## ------- HAUSDORFF  ----------
        hausdorff = calc_hausdorff(target_img, pred_img)

        if np.isfinite(hausdorff) and hausdorff > 0:
          hausdorff_metric.append(hausdorff)

        ## ------- RAPORT ----------

        line = f"Obraz i={i+1}, ssim={ssim_metric[-1]}, lpips={lpips_metric[-1]}, flip={flip_metric[-1]}, hausdorff={hausdorff}\n"
        mertric_str += line

        print(line)
        i += 1

  avg_ssim = np.mean(ssim_metric)
  avg_lpips =  np.mean(lpips_metric)
  avg_flip = np.mean(flip_metric)
  avg_hausdorff = np.mean(hausdorff_metric)

  if result_folder:
    os.makedirs(result_folder, exist_ok=True)
    mertric_str += f"\n\n### METRYKI DLA ZBIORU TESTOWEGO ###\n\n\tssim={avg_ssim}, lpips={avg_lpips}, flip={avg_flip}, hausdorff={avg_hausdorff}"
    with open(f"{result_folder}/metryki.txt", "w") as f:
      f.write(mertric_str)

  return avg_ssim, avg_lpips, avg_flip, avg_hausdorff

# %%
avg_ssim, avg_lpips, avg_flip, avg_hausdorff = calc_metrics(gen, DEVICE, result_folder=result_folder)
print(f"Metryki dla zbioru testowego: ssim={avg_ssim}, lpips={avg_lpips}, flip={avg_flip}, hausdorff={avg_hausdorff}")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SqueezeNet1_1_Weights.IMAGENET1K_V1`. You can also use `weights=SqueezeNet1_1_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Urządzenie: cpu
# Setting up [LPIPS] perceptual loss: trunk [squeeze], v[0.1], spatial [off]
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
# 100%|██████████| 4.73M/4.73M [00:00<00:00, 82.2MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/squeeze.pth
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6980392336845398
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.3960784673690796
# Obraz i=1, ssim=0.4789511813240912, lpips=0.19133834540843964, flip=0.06548003852367401, hausdorff=69.06518659932803
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=2, ssim=0.7182813005848633, lpips=0.165259450674057, flip=0.0808461606502533, hausdorff=59.50630218724736
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=3, ssim=0.7172424078122503, lpips=0.194285050034523, flip=0.019509145990014076, hausdorff=62.76941930590086
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9058823585510254
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8117647171020508
# Obraz i=4, ssim=0.7381929989161514, lpips=0.2420886754989624, flip=0.1785043329000473, hausdorff=30.675723300355934
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.12941177189350128
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7411764860153198
# Obraz i=5, ssim=0.8545347241544565, lpips=0.19527344405651093, flip=0.016948863863945007, hausdorff=42.720018726587654
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8039215803146362
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6078431606292725
# Obraz i=6, ssim=0.6214844090415038, lpips=0.20492450892925262, flip=0.12064703553915024, hausdorff=29.068883707497267
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.3960784375667572
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.2078431248664856
# Obraz i=7, ssim=0.7512020849328689, lpips=0.12489660084247589, flip=0.02028859220445156, hausdorff=120.8056290079233
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=8, ssim=0.7109107876724314, lpips=0.1270788609981537, flip=0.10807695984840393, hausdorff=35.77708763999664
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6627451181411743
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.32549023628234863
# Obraz i=9, ssim=0.715939003967616, lpips=0.16221849620342255, flip=0.10796578973531723, hausdorff=21.633307652783937
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.772549033164978
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.545098066329956
# Obraz i=10, ssim=0.7291746307999297, lpips=0.16627469658851624, flip=0.04929207265377045, hausdorff=48.08326112068523
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6745098233222961
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.3490196466445923
# Obraz i=11, ssim=0.710665802885695, lpips=0.17896762490272522, flip=0.027586273849010468, hausdorff=57.688820407423826
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=12, ssim=0.7708964680362104, lpips=0.19064249098300934, flip=0.02451547421514988, hausdorff=59.30430001273095
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=13, ssim=0.6542825860059717, lpips=0.2082824409008026, flip=0.03441315144300461, hausdorff=61.40032573203501
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=14, ssim=0.614557685051195, lpips=0.2483857274055481, flip=0.09588353335857391, hausdorff=60.876925020897694
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8823529481887817
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7647058963775635
# Obraz i=15, ssim=0.8221429592165341, lpips=0.1428442895412445, flip=0.059268008917570114, hausdorff=37.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6901960968971252
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.3803921937942505
# Obraz i=16, ssim=0.7449069938202352, lpips=0.12874998152256012, flip=0.035626281052827835, hausdorff=20.808652046684813
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.13725490868091583
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7254902124404907
# Obraz i=17, ssim=0.6208601346972685, lpips=0.21576571464538574, flip=0.052163541316986084, hausdorff=62.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=18, ssim=0.787051439897858, lpips=0.21192610263824463, flip=0.01791347935795784, hausdorff=40.311288741492746
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.843137264251709
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.686274528503418
# Obraz i=19, ssim=0.8212445092586842, lpips=0.10732812434434891, flip=0.027198437601327896, hausdorff=41.773197148410844
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9607843160629272
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9215686321258545
# Obraz i=20, ssim=0.7318204855475626, lpips=0.11899131536483765, flip=0.06586264073848724, hausdorff=38.27531841800928
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8941176533699036
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7882353067398071
# Obraz i=21, ssim=0.728589111109638, lpips=0.11923153698444366, flip=0.08785684406757355, hausdorff=33.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8980392217636108
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7960784435272217
# Obraz i=22, ssim=0.7854516671047677, lpips=0.14075712859630585, flip=0.07090109586715698, hausdorff=26.90724809414742
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9647058844566345
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.929411768913269
# Obraz i=23, ssim=0.6949275196638526, lpips=0.18393824994564056, flip=0.0936494767665863, hausdorff=25.019992006393608
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9647058844566345
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.929411768913269
# Obraz i=24, ssim=0.8111032256337204, lpips=0.08831228315830231, flip=0.0497305653989315, hausdorff=38.2099463490856
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7372549176216125
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.4745098352432251
# Obraz i=25, ssim=0.7694390491323989, lpips=0.10982412844896317, flip=0.092867411673069, hausdorff=13.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.3294117748737335
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.34117645025253296
# Obraz i=26, ssim=0.6854426901825379, lpips=0.14190568029880524, flip=0.04236253723502159, hausdorff=45.617978911828175
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.06666667014360428
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8666666746139526
# Obraz i=27, ssim=0.7869870805155236, lpips=0.17568014562129974, flip=0.027400599792599678, hausdorff=17.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=28, ssim=0.5116590345158915, lpips=0.27218490839004517, flip=0.22357919812202454, hausdorff=31.575306807693888
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.800000011920929
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6000000238418579
# Obraz i=29, ssim=0.780141836453224, lpips=0.11601611971855164, flip=0.09164394438266754, hausdorff=11.661903789690601
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9058823585510254
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8117647171020508
# Obraz i=30, ssim=0.7489075003059481, lpips=0.13153937458992004, flip=0.08325676620006561, hausdorff=47.4236228055175
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=31, ssim=0.8521429215729576, lpips=0.09190109372138977, flip=0.06076655164361, hausdorff=10.63014581273465
#
# 	target_img_f: min=0.0, max=0.6039215922355652
# 	pred_img_f: min=0.0, max=0.21568627655506134
# 	target_tensor: min=-1.0, max=0.20784318447113037
# 	pred_tensor: min=-1.0, max=-0.5686274766921997
# Obraz i=32, ssim=0.8295968796597332, lpips=0.08512349426746368, flip=0.016491813585162163, hausdorff=20.223748416156685
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.15294118225574493
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.6941176652908325
# Obraz i=33, ssim=0.8069441081848009, lpips=0.14340218901634216, flip=0.02599884755909443, hausdorff=51.78802950489621
#
# 	target_img_f: min=0.0, max=0.8039215803146362
# 	pred_img_f: min=0.0, max=0.9098039269447327
# 	target_tensor: min=-1.0, max=0.6078431606292725
# 	pred_tensor: min=-1.0, max=0.8196078538894653
# Obraz i=34, ssim=0.6115061709420374, lpips=0.19515924155712128, flip=0.0953836515545845, hausdorff=34.058772731852805
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5176470875740051
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.035294175148010254
# Obraz i=35, ssim=0.7424973266745822, lpips=0.1297529637813568, flip=0.04459520801901817, hausdorff=62.00806399170998
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5882353186607361
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.17647063732147217
# Obraz i=36, ssim=0.6992682447880966, lpips=0.17494820058345795, flip=0.02362181432545185, hausdorff=52.40229002629561
#
# 	target_img_f: min=0.0, max=0.6666666865348816
# 	pred_img_f: min=0.0, max=0.5921568870544434
# 	target_tensor: min=-1.0, max=0.3333333730697632
# 	pred_tensor: min=-1.0, max=0.18431377410888672
# Obraz i=37, ssim=0.6544991740744215, lpips=0.15458589792251587, flip=0.022950459271669388, hausdorff=43.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6627451181411743
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.32549023628234863
# Obraz i=38, ssim=0.6911987111017543, lpips=0.1989104449748993, flip=0.05872713774442673, hausdorff=26.0
#
# 	target_img_f: min=0.0, max=0.2705882489681244
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=-0.4588235020637512
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=39, ssim=0.7426253757690612, lpips=0.09636509418487549, flip=0.007458950392901897, hausdorff=70.8801805866774
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=40, ssim=0.7208340924124751, lpips=0.13624614477157593, flip=0.03400828316807747, hausdorff=57.0701322935211
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.95686274766922
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9137254953384399
# Obraz i=41, ssim=0.7117593166185635, lpips=0.14633379876613617, flip=0.06258340179920197, hausdorff=71.449282711585
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=42, ssim=0.7646275375220165, lpips=0.15172912180423737, flip=0.02128126472234726, hausdorff=45.967379738244816
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.250980406999588
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.498039186000824
# Obraz i=43, ssim=0.74090409288715, lpips=0.12698650360107422, flip=0.029403552412986755, hausdorff=62.76941930590086
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5058823823928833
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.011764764785766602
# Obraz i=44, ssim=0.6739590003629514, lpips=0.20743852853775024, flip=0.05024914816021919, hausdorff=82.00609733428362
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8941176533699036
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7882353067398071
# Obraz i=45, ssim=0.512321707204205, lpips=0.2782849073410034, flip=0.10882753133773804, hausdorff=70.00714249274856
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9921568632125854
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9843137264251709
# Obraz i=46, ssim=0.6721127750264824, lpips=0.1842520385980606, flip=0.057482894510030746, hausdorff=53.08483775994799
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9411764740943909
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8823529481887817
# Obraz i=47, ssim=0.6181140090210068, lpips=0.2376120686531067, flip=0.13187895715236664, hausdorff=26.419689627245813
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.886274516582489
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.772549033164978
# Obraz i=48, ssim=0.7805718737830838, lpips=0.08916880935430527, flip=0.03409089520573616, hausdorff=7.615773105863909
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=49, ssim=0.7496105932178345, lpips=0.10349975526332855, flip=0.08247983455657959, hausdorff=13.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=50, ssim=0.7978481333514403, lpips=0.13077418506145477, flip=0.016763165593147278, hausdorff=75.05997601918082
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9450980424880981
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8901960849761963
# Obraz i=51, ssim=0.6564190392608142, lpips=0.22298505902290344, flip=0.14751692116260529, hausdorff=30.14962686336267
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=52, ssim=0.6655468197332499, lpips=0.14413346350193024, flip=0.028163252398371696, hausdorff=54.08326913195984
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9529411792755127
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9058823585510254
# Obraz i=53, ssim=0.7886623978067252, lpips=0.07919333875179291, flip=0.03692825138568878, hausdorff=56.302753041036986
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8901960849761963
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7803921699523926
# Obraz i=54, ssim=0.8048767175226734, lpips=0.13810496032238007, flip=0.062050022184848785, hausdorff=18.0
#
# 	target_img_f: min=0.0, max=0.9960784316062927
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=0.9921568632125854
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=55, ssim=0.7535044025464722, lpips=0.21314585208892822, flip=0.01620921865105629, hausdorff=76.47875521999558
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.13333334028720856
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7333333492279053
# Obraz i=56, ssim=0.788343245967028, lpips=0.10036207735538483, flip=0.02536110393702984, hausdorff=63.702433234531945
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=57, ssim=0.762036972381981, lpips=0.11647691577672958, flip=0.04138701409101486, hausdorff=49.040799340956916
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9686274528503418
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9372549057006836
# Obraz i=58, ssim=0.7529701346757856, lpips=0.13218975067138672, flip=0.04208562895655632, hausdorff=42.44997055358225
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9450980424880981
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8901960849761963
# Obraz i=59, ssim=0.7848945169111862, lpips=0.09660801291465759, flip=0.0655440166592598, hausdorff=56.61271941887264
#
# 	target_img_f: min=0.0, max=0.9803921580314636
# 	pred_img_f: min=0.0, max=0.32549020648002625
# 	target_tensor: min=-1.0, max=0.9607843160629272
# 	pred_tensor: min=-1.0, max=-0.3490195870399475
# Obraz i=60, ssim=0.7184048479811834, lpips=0.2320106327533722, flip=0.048270974308252335, hausdorff=67.67569726275453
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9176470637321472
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8352941274642944
# Obraz i=61, ssim=0.7156067087368507, lpips=0.14332354068756104, flip=0.043049804866313934, hausdorff=32.89376840679705
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.4431372582912445
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.11372548341751099
# Obraz i=62, ssim=0.7842469411153076, lpips=0.09257597476243973, flip=0.01863255724310875, hausdorff=23.08679276123039
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7490196228027344
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.49803924560546875
# Obraz i=63, ssim=0.7282338302634557, lpips=0.23763546347618103, flip=0.042859870940446854, hausdorff=82.49242389456137
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=64, ssim=0.7583636849324972, lpips=0.13084648549556732, flip=0.06360259652137756, hausdorff=37.656340767525464
#
# 	target_img_f: min=0.0, max=0.9450980424880981
# 	pred_img_f: min=0.0, max=0.47058823704719543
# 	target_tensor: min=-1.0, max=0.8901960849761963
# 	pred_tensor: min=-1.0, max=-0.05882352590560913
# Obraz i=65, ssim=0.6129169740676099, lpips=0.13583731651306152, flip=0.026692572981119156, hausdorff=41.10960958218893
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.10980392247438431
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7803921699523926
# Obraz i=66, ssim=0.7784182947820275, lpips=0.18415942788124084, flip=0.020687012001872063, hausdorff=81.30190649671138
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9843137264251709
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9686274528503418
# Obraz i=67, ssim=0.5223919181992587, lpips=0.2193537801504135, flip=0.052959274500608444, hausdorff=79.47955712005447
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.3137255012989044
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.37254899740219116
# Obraz i=68, ssim=0.7509673424975615, lpips=0.15198668837547302, flip=0.035927992314100266, hausdorff=13.601470508735444
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9764705896377563
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9529411792755127
# Obraz i=69, ssim=0.23568630409422467, lpips=0.32119590044021606, flip=0.29219138622283936, hausdorff=46.010868281309364
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=70, ssim=0.47692358309106514, lpips=0.25896552205085754, flip=0.17506694793701172, hausdorff=29.068883707497267
#
# 	target_img_f: min=0.0, max=0.9843137264251709
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=0.9686274528503418
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=71, ssim=0.7562981426487103, lpips=0.1921742558479309, flip=0.017488889396190643, hausdorff=76.53757247260981
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8235294222831726
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6470588445663452
# Obraz i=72, ssim=0.6584891002327637, lpips=0.1917232722043991, flip=0.11818716675043106, hausdorff=26.419689627245813
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9529411792755127
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9058823585510254
# Obraz i=73, ssim=0.6830479163625448, lpips=0.17330226302146912, flip=0.05184658616781235, hausdorff=78.24321056807422
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=74, ssim=0.6275734482420408, lpips=0.20309562981128693, flip=0.03503307327628136, hausdorff=51.07837115648854
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9490196108818054
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8980392217636108
# Obraz i=75, ssim=0.7888528928776092, lpips=0.10767845064401627, flip=0.04048328846693039, hausdorff=28.460498941515414
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.22745098173618317
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.545098066329956
# Obraz i=76, ssim=0.8414676116736306, lpips=0.16031326353549957, flip=0.028130318969488144, hausdorff=62.177166226839255
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.21568627655506134
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.5686274766921997
# Obraz i=77, ssim=0.8470724013151214, lpips=0.1305016577243805, flip=0.02491864375770092, hausdorff=70.21395872616783
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7137255072593689
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.4274510145187378
# Obraz i=78, ssim=0.616468738791295, lpips=0.18144239485263824, flip=0.05391009896993637, hausdorff=81.54140052758476
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8941176533699036
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7882353067398071
# Obraz i=79, ssim=0.7729111607207143, lpips=0.11101775616407394, flip=0.09857571870088577, hausdorff=13.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=80, ssim=0.800947884221284, lpips=0.1555853933095932, flip=0.015091918408870697, hausdorff=24.166091947189145
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9529411792755127
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9058823585510254
# Obraz i=81, ssim=0.7651498074485447, lpips=0.09719875454902649, flip=0.05136281996965408, hausdorff=30.23243291566195
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=82, ssim=0.6547667671974937, lpips=0.19243767857551575, flip=0.1138022243976593, hausdorff=22.360679774997898
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5764706134796143
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.15294122695922852
# Obraz i=83, ssim=0.7532017907103641, lpips=0.12713871896266937, flip=0.06094546243548393, hausdorff=31.953090617340916
#
# 	target_img_f: min=0.0, max=0.9529411792755127
# 	pred_img_f: min=0.0, max=0.7372549176216125
# 	target_tensor: min=-1.0, max=0.9058823585510254
# 	pred_tensor: min=-1.0, max=0.4745098352432251
# Obraz i=84, ssim=0.5750711675102639, lpips=0.16180205345153809, flip=0.03465600311756134, hausdorff=101.55294185792945
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9411764740943909
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8823529481887817
# Obraz i=85, ssim=0.7107012836391364, lpips=0.12872889637947083, flip=0.11270634084939957, hausdorff=22.360679774997898
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5960784554481506
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.19215691089630127
# Obraz i=86, ssim=0.7331404236096771, lpips=0.09164019674062729, flip=0.0494275838136673, hausdorff=17.88854381999832
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7529411911964417
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.5058823823928833
# Obraz i=87, ssim=0.6641661642848287, lpips=0.1339828372001648, flip=0.050711940973997116, hausdorff=20.248456731316587
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.08235294371843338
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8352941274642944
# Obraz i=88, ssim=0.7522940360219258, lpips=0.1858803778886795, flip=0.02326476387679577, hausdorff=67.47592163134935
#
# 	target_img_f: min=0.0, max=0.054901961237192154
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=-0.8901960849761963
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=89, ssim=0.7789584917369584, lpips=0.07497983425855637, flip=0.0120158726349473, hausdorff=101.31633629380802
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8823529481887817
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7647058963775635
# Obraz i=90, ssim=0.8113017411591272, lpips=0.10341650247573853, flip=0.04367833212018013, hausdorff=22.47220505424423
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6117647290229797
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.22352945804595947
# Obraz i=91, ssim=0.7222466784979168, lpips=0.15976688265800476, flip=0.09001778811216354, hausdorff=41.88078318274385
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=92, ssim=0.8096186800577021, lpips=0.1717020869255066, flip=0.01890256442129612, hausdorff=67.446274915669
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9529411792755127
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9058823585510254
# Obraz i=93, ssim=0.5507488715908425, lpips=0.1860264539718628, flip=0.10792426764965057, hausdorff=29.068883707497267
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5058823823928833
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.011764764785766602
# Obraz i=94, ssim=0.8086480124621797, lpips=0.19557757675647736, flip=0.024961940944194794, hausdorff=44.27188724235731
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=95, ssim=0.8051634349081351, lpips=0.09717893600463867, flip=0.03760940209031105, hausdorff=17.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9137254953384399
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8274509906768799
# Obraz i=96, ssim=0.45878034480628577, lpips=0.2261909693479538, flip=0.13220439851284027, hausdorff=42.42640687119285
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.0784313753247261
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.843137264251709
# Obraz i=97, ssim=0.6116149278281072, lpips=0.23379454016685486, flip=0.03975218906998634, hausdorff=42.04759208325728
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.772549033164978
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.545098066329956
# Obraz i=98, ssim=0.8351223219746692, lpips=0.09313615411520004, flip=0.017241274937987328, hausdorff=11.180339887498949
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.13725490868091583
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7254902124404907
# Obraz i=99, ssim=0.6418306907185656, lpips=0.20140327513217926, flip=0.04154472053050995, hausdorff=57.245087125446844
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.09803921729326248
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8039215803146362
# Obraz i=100, ssim=0.7396453617553691, lpips=0.14806866645812988, flip=0.026096424087882042, hausdorff=37.12142238654117
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=101, ssim=0.8267366062301887, lpips=0.10085219144821167, flip=0.02521427720785141, hausdorff=37.21558813185679
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8784313797950745
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7568627595901489
# Obraz i=102, ssim=0.559017619495375, lpips=0.1839357167482376, flip=0.06276022642850876, hausdorff=63.56099432828282
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=103, ssim=0.6920239131900265, lpips=0.2126435488462448, flip=0.03063989244401455, hausdorff=51.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6117647290229797
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.22352945804595947
# Obraz i=104, ssim=0.7303973372224868, lpips=0.25041911005973816, flip=0.04107356071472168, hausdorff=10.295630140987
#
# 	target_img_f: min=0.0, max=0.5058823823928833
# 	pred_img_f: min=0.0, max=0.8666666746139526
# 	target_tensor: min=-1.0, max=0.011764764785766602
# 	pred_tensor: min=-1.0, max=0.7333333492279053
# Obraz i=105, ssim=0.5213186689674104, lpips=0.19446900486946106, flip=0.05036766082048416, hausdorff=48.041648597857254
#
# 	target_img_f: min=0.0, max=0.9764705896377563
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=0.9529411792755127
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=106, ssim=0.6700278246758203, lpips=0.22459718585014343, flip=0.02398393116891384, hausdorff=85.492689745966
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9333333373069763
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8666666746139526
# Obraz i=107, ssim=0.6837740088768968, lpips=0.13301633298397064, flip=0.07186435908079147, hausdorff=46.57252408878007
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9647058844566345
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.929411768913269
# Obraz i=108, ssim=0.6339446886795312, lpips=0.17701363563537598, flip=0.08702337741851807, hausdorff=31.32091952673165
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=109, ssim=0.5202644346643803, lpips=0.19962067902088165, flip=0.0828365907073021, hausdorff=52.15361924162119
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=110, ssim=0.7452091060928866, lpips=0.10974906384944916, flip=0.10062282532453537, hausdorff=25.96150997149434
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8313725590705872
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6627451181411743
# Obraz i=111, ssim=0.6873711498401254, lpips=0.18836581707000732, flip=0.06263788789510727, hausdorff=31.064449134018133
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9647058844566345
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.929411768913269
# Obraz i=112, ssim=0.7906610513982182, lpips=0.07417813688516617, flip=0.03265460953116417, hausdorff=45.45327270945405
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8627451062202454
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7254902124404907
# Obraz i=113, ssim=0.8054108093156445, lpips=0.07588440179824829, flip=0.04197056218981743, hausdorff=9.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.929411768913269
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8588235378265381
# Obraz i=114, ssim=0.7377164453326387, lpips=0.10019144415855408, flip=0.13851957023143768, hausdorff=21.93171219946131
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.843137264251709
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.686274528503418
# Obraz i=115, ssim=0.6162990505203241, lpips=0.26207512617111206, flip=0.23644526302814484, hausdorff=22.847319317591726
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=116, ssim=0.6970987212904828, lpips=0.1471109688282013, flip=0.07199577242136002, hausdorff=40.049968789001575
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=117, ssim=0.8167848423144198, lpips=0.18449273705482483, flip=0.019960297271609306, hausdorff=70.02856560004639
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=118, ssim=0.735791644405383, lpips=0.14516755938529968, flip=0.023738818243145943, hausdorff=72.91776189653656
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9529411792755127
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9058823585510254
# Obraz i=119, ssim=0.8161266636891523, lpips=0.11227289587259293, flip=0.04165234789252281, hausdorff=27.018512172212592
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.2235294133424759
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.5529412031173706
# Obraz i=120, ssim=0.7864524256743191, lpips=0.11098538339138031, flip=0.01727060042321682, hausdorff=18.384776310850235
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8823529481887817
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7647058963775635
# Obraz i=121, ssim=0.7791211399620391, lpips=0.16808883845806122, flip=0.02616150490939617, hausdorff=9.219544457292887
#
# 	target_img_f: min=0.0, max=0.32549020648002625
# 	pred_img_f: min=0.0, max=0.07058823853731155
# 	target_tensor: min=-1.0, max=-0.3490195870399475
# 	pred_tensor: min=-1.0, max=-0.8588235378265381
# Obraz i=122, ssim=0.7337560994613538, lpips=0.14610180258750916, flip=0.015066144056618214, hausdorff=41.012193308819754
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7803921699523926
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.5607843399047852
# Obraz i=123, ssim=0.7397428088972823, lpips=0.16391196846961975, flip=0.11971665918827057, hausdorff=15.132745950421556
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.1411764770746231
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7176470756530762
# Obraz i=124, ssim=0.7041811366550951, lpips=0.1446879357099533, flip=0.03155586123466492, hausdorff=59.033888572581766
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.4588235318660736
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.08235293626785278
# Obraz i=125, ssim=0.7234914585457174, lpips=0.11171276867389679, flip=0.03178070858120918, hausdorff=20.615528128088304
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7372549176216125
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.4745098352432251
# Obraz i=126, ssim=0.7878519551947575, lpips=0.1333276480436325, flip=0.025921687483787537, hausdorff=11.313708498984761
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6470588445663452
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.29411768913269043
# Obraz i=127, ssim=0.7939363936734017, lpips=0.11376474052667618, flip=0.019476918503642082, hausdorff=47.80167361086848
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.07450980693101883
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8509804010391235
# Obraz i=128, ssim=0.8068601396043417, lpips=0.11780878156423569, flip=0.0223236046731472, hausdorff=20.518284528683193
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=129, ssim=0.7694732481489241, lpips=0.18207572400569916, flip=0.02419227547943592, hausdorff=81.39410298049853
#
# 	target_img_f: min=0.0, max=0.29411765933036804
# 	pred_img_f: min=0.0, max=0.15294118225574493
# 	target_tensor: min=-1.0, max=-0.4117646813392639
# 	pred_tensor: min=-1.0, max=-0.6941176652908325
# Obraz i=130, ssim=0.7952346664178571, lpips=0.09259746223688126, flip=0.009078563190996647, hausdorff=40.496913462633174
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.29019609093666077
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.41960781812667847
# Obraz i=131, ssim=0.8093900369053518, lpips=0.15473687648773193, flip=0.016795817762613297, hausdorff=59.07622195096772
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9450980424880981
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8901960849761963
# Obraz i=132, ssim=0.7663247488680379, lpips=0.14426012337207794, flip=0.0701046884059906, hausdorff=34.132096331752024
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6980392336845398
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.3960784673690796
# Obraz i=133, ssim=0.7879095076170467, lpips=0.1482188105583191, flip=0.03289294242858887, hausdorff=19.697715603592208
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.46666666865348816
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.06666666269302368
# Obraz i=134, ssim=0.7663551271835836, lpips=0.12573052942752838, flip=0.025414129719138145, hausdorff=77.3692445355388
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8117647171020508
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6235294342041016
# Obraz i=135, ssim=0.5766836415554533, lpips=0.22095218300819397, flip=0.07456503808498383, hausdorff=37.21558813185679
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.2823529541492462
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.43529409170150757
# Obraz i=136, ssim=0.730449160236471, lpips=0.15687060356140137, flip=0.04746166989207268, hausdorff=58.215118311311535
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.04313725605607033
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9137254953384399
# Obraz i=137, ssim=0.7474125071250034, lpips=0.200395867228508, flip=0.025748763233423233, hausdorff=45.12205669071391
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=138, ssim=0.6061279359698132, lpips=0.21674634516239166, flip=0.12484544515609741, hausdorff=39.81205847478876
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7960784435272217
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.5921568870544434
# Obraz i=139, ssim=0.8551922936320776, lpips=0.07166583836078644, flip=0.07223250716924667, hausdorff=10.770329614269007
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.239215686917305
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.5215686559677124
# Obraz i=140, ssim=0.769244273253831, lpips=0.12170712649822235, flip=0.032331351190805435, hausdorff=61.814237842102365
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=141, ssim=0.7976992637531103, lpips=0.1553916335105896, flip=0.01607869192957878, hausdorff=60.01666435249463
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.658823549747467
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.3176470994949341
# Obraz i=142, ssim=0.5432815367294764, lpips=0.2934284806251526, flip=0.14593739807605743, hausdorff=59.90826320300064
#
# 	target_img_f: min=0.0, max=0.43921568989753723
# 	pred_img_f: min=0.0, max=0.04313725605607033
# 	target_tensor: min=-1.0, max=-0.12156862020492554
# 	pred_tensor: min=-1.0, max=-0.9137254953384399
# Obraz i=143, ssim=0.6068039481102341, lpips=0.21985462307929993, flip=0.018074577674269676, hausdorff=54.230987451824994
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.14509804546833038
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7098039388656616
# Obraz i=144, ssim=0.8096931436696212, lpips=0.12192699313163757, flip=0.020246295258402824, hausdorff=43.18564576337837
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.572549045085907
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.14509809017181396
# Obraz i=145, ssim=0.752509585542422, lpips=0.1897730827331543, flip=0.03461071103811264, hausdorff=43.41658669218482
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=146, ssim=0.8059884704342407, lpips=0.1391296684741974, flip=0.03316369280219078, hausdorff=90.0499861188218
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.95686274766922
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9137254953384399
# Obraz i=147, ssim=0.7588982336835463, lpips=0.11441531777381897, flip=0.0474805049598217, hausdorff=29.154759474226502
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7764706015586853
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.5529412031173706
# Obraz i=148, ssim=0.685992069094505, lpips=0.17190958559513092, flip=0.05652498081326485, hausdorff=21.18962010041709
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=149, ssim=0.7378132008385125, lpips=0.28447726368904114, flip=0.04276511073112488, hausdorff=64.47480127925948
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5411764979362488
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.08235299587249756
# Obraz i=150, ssim=0.7558866374119567, lpips=0.20272396504878998, flip=0.0404670387506485, hausdorff=17.0
#
# 	target_img_f: min=0.0, max=0.9764705896377563
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=0.9529411792755127
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=151, ssim=0.7860974076607389, lpips=0.2329377382993698, flip=0.03161758929491043, hausdorff=22.847319317591726
#
# 	target_img_f: min=0.0, max=0.06666667014360428
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=-0.8666666746139526
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=152, ssim=0.6428869316945116, lpips=0.14706309139728546, flip=0.012937625870108604, hausdorff=77.31752712031083
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=153, ssim=0.7222755922407679, lpips=0.18431566655635834, flip=0.13583101332187653, hausdorff=38.948684188300895
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.886274516582489
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.772549033164978
# Obraz i=154, ssim=0.7504400885490474, lpips=0.0969710648059845, flip=0.10233806073665619, hausdorff=32.449961479175904
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.054901961237192154
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8901960849761963
# Obraz i=155, ssim=0.7028618280938783, lpips=0.2096470296382904, flip=0.04549236223101616, hausdorff=67.67569726275453
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=156, ssim=0.7333439640335562, lpips=0.13111411035060883, flip=0.20569172501564026, hausdorff=25.238858928247925
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.054901961237192154
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8901960849761963
# Obraz i=157, ssim=0.8500474247328672, lpips=0.14471817016601562, flip=0.015257399529218674, hausdorff=43.08131845707603
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=158, ssim=0.4479807754215103, lpips=0.26565462350845337, flip=0.1714315265417099, hausdorff=34.23448553724738
#
# 	target_img_f: min=0.0, max=0.9647058844566345
# 	pred_img_f: min=0.0, max=0.03921568766236305
# 	target_tensor: min=-1.0, max=0.929411768913269
# 	pred_tensor: min=-1.0, max=-0.9215686321258545
# Obraz i=159, ssim=0.8255909745592596, lpips=0.20236796140670776, flip=0.023061903193593025, hausdorff=102.6498904042279
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6705882549285889
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.34117650985717773
# Obraz i=160, ssim=0.7801120674243002, lpips=0.11622335761785507, flip=0.12244120985269547, hausdorff=39.21734310225516
#
# 	target_img_f: min=0.0, max=0.9215686321258545
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=0.843137264251709
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=161, ssim=0.709469181024831, lpips=0.20565815269947052, flip=0.017552169039845467, hausdorff=56.60388679233962
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.07058823853731155
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8588235378265381
# Obraz i=162, ssim=0.7643717617056266, lpips=0.20183774828910828, flip=0.026008250191807747, hausdorff=66.03029607687671
#
# 	target_img_f: min=0.0, max=0.8392156958580017
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=0.6784313917160034
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=163, ssim=0.5861244202554138, lpips=0.2425099015235901, flip=0.026902878656983376, hausdorff=40.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8392156958580017
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6784313917160034
# Obraz i=164, ssim=0.7268325597989774, lpips=0.1633094698190689, flip=0.048745863139629364, hausdorff=66.09841147864296
#
# 	target_img_f: min=0.0, max=0.3450980484485626
# 	pred_img_f: min=0.0, max=0.32549020648002625
# 	target_tensor: min=-1.0, max=-0.30980390310287476
# 	pred_tensor: min=-1.0, max=-0.3490195870399475
# Obraz i=165, ssim=0.8018052696275895, lpips=0.07342414557933807, flip=0.008319263346493244, hausdorff=33.95585369269929
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.4431372582912445
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.11372548341751099
# Obraz i=166, ssim=0.7643407460324378, lpips=0.16438180208206177, flip=0.04437163844704628, hausdorff=20.591260281974
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5372549295425415
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.07450985908508301
# Obraz i=167, ssim=0.7397996294816132, lpips=0.1626873016357422, flip=0.09880093485116959, hausdorff=24.20743687382041
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9137254953384399
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8274509906768799
# Obraz i=168, ssim=0.7585481848008985, lpips=0.16864338517189026, flip=0.07292057573795319, hausdorff=51.478150704935004
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# ...
# 	pred_tensor: min=-1.0, max=0.8588235378265381
# Obraz i=544, ssim=0.46694793228727827, lpips=0.31190231442451477, flip=0.23933270573616028, hausdorff=39.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9843137264251709
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9686274528503418
# Obraz i=545, ssim=0.7760018984707493, lpips=0.1667579859495163, flip=0.08484502136707306, hausdorff=23.194827009486403
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.054901961237192154
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8901960849761963
# Obraz i=546, ssim=0.8393127837787464, lpips=0.14838528633117676, flip=0.02104436792433262, hausdorff=61.032778078668514
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9803921580314636
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9607843160629272
# Obraz i=547, ssim=0.7147808583983033, lpips=0.11450986564159393, flip=0.047347091138362885, hausdorff=38.948684188300895
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8509804010391235
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7019608020782471
# Obraz i=548, ssim=0.8563058952905666, lpips=0.060990288853645325, flip=0.035553134977817535, hausdorff=9.848857801796104
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=549, ssim=0.8040178257558864, lpips=0.15547999739646912, flip=0.08392061293125153, hausdorff=20.223748416156685
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9725490212440491
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9450980424880981
# Obraz i=550, ssim=0.7521457639398913, lpips=0.15103799104690552, flip=0.07252106070518494, hausdorff=44.384682042344295
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.09019608050584793
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8196078538894653
# Obraz i=551, ssim=0.5417871534810167, lpips=0.17678651213645935, flip=0.03838822618126869, hausdorff=44.04543109109048
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.3960784375667572
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.2078431248664856
# Obraz i=552, ssim=0.7850775566802385, lpips=0.1404370814561844, flip=0.02512277662754059, hausdorff=26.90724809414742
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.03529411926865578
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.929411768913269
# Obraz i=553, ssim=0.7303615157800443, lpips=0.1707693487405777, flip=0.023409100249409676, hausdorff=48.75448697299562
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5960784554481506
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.19215691089630127
# Obraz i=554, ssim=0.7749803167393097, lpips=0.1375192105770111, flip=0.03194942697882652, hausdorff=47.16990566028302
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8509804010391235
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7019608020782471
# Obraz i=555, ssim=0.294337766231528, lpips=0.2230452448129654, flip=0.19670376181602478, hausdorff=75.8023746329889
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9686274528503418
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9372549057006836
# Obraz i=556, ssim=0.6211160910346138, lpips=0.2226465344429016, flip=0.10187776386737823, hausdorff=47.20169488482379
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.41960784792900085
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.1607843041419983
# Obraz i=557, ssim=0.654629572542852, lpips=0.19083791971206665, flip=0.08069247752428055, hausdorff=47.01063709417264
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9490196108818054
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8980392217636108
# Obraz i=558, ssim=0.7919613652782894, lpips=0.11170962452888489, flip=0.09326263517141342, hausdorff=15.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5568627715110779
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.11372554302215576
# Obraz i=559, ssim=0.7773063911895951, lpips=0.1219019666314125, flip=0.03024139069020748, hausdorff=44.77722635447622
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.46666666865348816
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.06666666269302368
# Obraz i=560, ssim=0.7706363789631392, lpips=0.17768654227256775, flip=0.04194904491305351, hausdorff=38.897300677553446
#
# 	target_img_f: min=0.0, max=0.3019607961177826
# 	pred_img_f: min=0.0, max=0.7137255072593689
# 	target_tensor: min=-1.0, max=-0.3960784077644348
# 	pred_tensor: min=-1.0, max=0.4274510145187378
# Obraz i=561, ssim=0.7359840713552438, lpips=0.11681601405143738, flip=0.03430548682808876, hausdorff=26.476404589747453
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=562, ssim=0.6057816959864971, lpips=0.1848226934671402, flip=0.04381507262587547, hausdorff=95.01578816175763
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9686274528503418
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9372549057006836
# Obraz i=563, ssim=0.652267663006557, lpips=0.25044775009155273, flip=0.11584068089723587, hausdorff=44.28317965096906
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.08235294371843338
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8352941274642944
# Obraz i=564, ssim=0.8357676243879192, lpips=0.1416052281856537, flip=0.02035016193985939, hausdorff=70.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.13333334028720856
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.7333333492279053
# Obraz i=565, ssim=0.6615777052398418, lpips=0.22533242404460907, flip=0.039084553718566895, hausdorff=54.70831746635972
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8509804010391235
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7019608020782471
# Obraz i=566, ssim=0.720069612724194, lpips=0.14279690384864807, flip=0.04479268193244934, hausdorff=11.045361017187261
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9490196108818054
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8980392217636108
# Obraz i=567, ssim=0.758755389142189, lpips=0.19136260449886322, flip=0.07988374680280685, hausdorff=36.89173349139343
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=568, ssim=0.6554166848987883, lpips=0.2760990858078003, flip=0.04423098638653755, hausdorff=66.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9686274528503418
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9372549057006836
# Obraz i=569, ssim=0.8319601142538695, lpips=0.0890200138092041, flip=0.04233173280954361, hausdorff=18.439088914585774
#
# 	target_img_f: min=0.0, max=0.48627451062202454
# 	pred_img_f: min=0.0, max=0.8941176533699036
# 	target_tensor: min=-1.0, max=-0.027450978755950928
# 	pred_tensor: min=-1.0, max=0.7882353067398071
# Obraz i=570, ssim=0.720525264085052, lpips=0.13094496726989746, flip=0.07500245422124863, hausdorff=32.7566787083184
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9725490212440491
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9450980424880981
# Obraz i=571, ssim=0.4907089861838669, lpips=0.24682477116584778, flip=0.10326740145683289, hausdorff=69.6419413859206
#
# 	target_img_f: min=0.0, max=0.9372549057006836
# 	pred_img_f: min=0.0, max=0.2705882489681244
# 	target_tensor: min=-1.0, max=0.8745098114013672
# 	pred_tensor: min=-1.0, max=-0.4588235020637512
# Obraz i=572, ssim=0.5604487309445153, lpips=0.2709733843803406, flip=0.045711398124694824, hausdorff=45.79301256742124
#
# 	target_img_f: min=0.0, max=0.8705882430076599
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=0.7411764860153198
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=573, ssim=0.7796755506586609, lpips=0.18354421854019165, flip=0.015091078355908394, hausdorff=76.6550715869472
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9843137264251709
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9686274528503418
# Obraz i=574, ssim=0.6147923995334358, lpips=0.15652520954608917, flip=0.07723342627286911, hausdorff=61.1310068623117
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6235294342041016
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.24705886840820312
# Obraz i=575, ssim=0.831764629060327, lpips=0.07887108623981476, flip=0.04463309422135353, hausdorff=8.54400374531753
#
# 	target_img_f: min=0.0, max=0.9764705896377563
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=0.9529411792755127
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=576, ssim=0.49746966698789213, lpips=0.20214882493019104, flip=0.057452742010354996, hausdorff=81.05553651663777
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=577, ssim=0.7800338024832455, lpips=0.25104814767837524, flip=0.03994959965348244, hausdorff=77.6659513557904
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.0470588244497776
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.9058823585510254
# Obraz i=578, ssim=0.7774272712627724, lpips=0.10310472548007965, flip=0.023316005244851112, hausdorff=72.53275122315436
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8823529481887817
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7647058963775635
# Obraz i=579, ssim=0.7212514797099788, lpips=0.15365691483020782, flip=0.1382066011428833, hausdorff=18.867962264113206
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=580, ssim=0.8016219673193788, lpips=0.13716934621334076, flip=0.05499167740345001, hausdorff=47.01063709417264
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8980392217636108
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.7960784435272217
# Obraz i=581, ssim=0.7310001157710838, lpips=0.19623474776744843, flip=0.17936156690120697, hausdorff=35.510561809129406
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.43529412150382996
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.1294117569923401
# Obraz i=582, ssim=0.6552175439987145, lpips=0.13036827743053436, flip=0.0489499606192112, hausdorff=28.160255680657446
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9607843160629272
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9215686321258545
# Obraz i=583, ssim=0.8206471229276623, lpips=0.12250830233097076, flip=0.028633063659071922, hausdorff=62.93647591023825
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.7137255072593689
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.4274510145187378
# Obraz i=584, ssim=0.7252250719906496, lpips=0.167354553937912, flip=0.03324542194604874, hausdorff=54.817880294662984
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.38823530077934265
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.2235293984413147
# Obraz i=585, ssim=0.8059508560796771, lpips=0.12005719542503357, flip=0.025929855182766914, hausdorff=10.0
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.20392157137393951
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.5921568870544434
# Obraz i=586, ssim=0.7564168630407138, lpips=0.09405260533094406, flip=0.02435528114438057, hausdorff=22.561028345356956
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9921568632125854
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9843137264251709
# Obraz i=587, ssim=0.6934667923731243, lpips=0.09713481366634369, flip=0.09563536196947098, hausdorff=31.622776601683793
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=1.0
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=1.0
# Obraz i=588, ssim=0.8295890982947783, lpips=0.09237056225538254, flip=0.07255237549543381, hausdorff=36.124783736376884
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6431372761726379
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.2862745523452759
# Obraz i=589, ssim=0.7491117916811026, lpips=0.12238822132349014, flip=0.023413414135575294, hausdorff=30.528675044947494
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.05098039284348488
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.8980392217636108
# Obraz i=590, ssim=0.6720210496860037, lpips=0.20374438166618347, flip=0.04630023613572121, hausdorff=63.06346010171025
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=591, ssim=0.8221718595838464, lpips=0.12360319495201111, flip=0.044977039098739624, hausdorff=38.948684188300895
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8156862854957581
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6313725709915161
# Obraz i=592, ssim=0.5901588129526083, lpips=0.20973999798297882, flip=0.10682427138090134, hausdorff=68.0294054067798
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.6705882549285889
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.34117650985717773
# Obraz i=593, ssim=0.8033914438180606, lpips=0.1074913889169693, flip=0.036667853593826294, hausdorff=15.132745950421556
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9882352948188782
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9764705896377563
# Obraz i=594, ssim=0.8296972006336724, lpips=0.10401733219623566, flip=0.04642002657055855, hausdorff=34.48187929913333
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9960784316062927
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.9921568632125854
# Obraz i=595, ssim=0.809411185688441, lpips=0.10443869978189468, flip=0.050618018954992294, hausdorff=48.877397639399746
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.8235294222831726
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.6470588445663452
# Obraz i=596, ssim=0.7793100452823785, lpips=0.14721916615962982, flip=0.0582495778799057, hausdorff=23.345235059857504
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.18431372940540314
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=-0.6313725709915161
# Obraz i=597, ssim=0.8330458682451368, lpips=0.09564504027366638, flip=0.023457232862710953, hausdorff=68.26419266350405
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.5843137502670288
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.16862750053405762
# Obraz i=598, ssim=0.7453823680039159, lpips=0.1716846376657486, flip=0.038181502372026443, hausdorff=8.0
#
# 	target_img_f: min=0.0, max=0.0313725508749485
# 	pred_img_f: min=0.0, max=0.27450981736183167
# 	target_tensor: min=-1.0, max=-0.9372549057006836
# 	pred_tensor: min=-1.0, max=-0.45098036527633667
# Obraz i=599, ssim=0.7626183799343508, lpips=0.06865499913692474, flip=0.01210641860961914, hausdorff=51.66236541235796
#
# 	target_img_f: min=0.0, max=1.0
# 	pred_img_f: min=0.0, max=0.9058823585510254
# 	target_tensor: min=-1.0, max=1.0
# 	pred_tensor: min=-1.0, max=0.8117647171020508
# Obraz i=600, ssim=0.3948466208701619, lpips=0.2932523190975189, flip=0.19100436568260193, hausdorff=38.897300677553446
#
# Metryki dla zbioru testowego: ssim=0.7275193134735486, lpips=0.15581165745854378, flip=0.05715355228632688, hausdorff=43.411287232707515
